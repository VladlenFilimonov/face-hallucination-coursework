# %%
import sys
sys.path.append('../')

import cv2
from matplotlib import pyplot as plt

# %%
image = cv2.imread('../notebook/inference-image/lr_img.png')
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
import inference

# %%
sr_img = inference.inference(image_rgb, '../epochs/netG_epoch_20.pth')
# Out:
# cost0.0022469000000455708s

# %%
plt.imshow(sr_img)
plt.axis('off')
plt.show()

# %%
original = cv2.imread('../notebook/inference-image/hr_img.png')
original_rgb = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)
plt.imshow(original_rgb)
plt.axis('off')  # Turn off axis
plt.show()
