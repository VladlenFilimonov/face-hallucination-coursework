# %%
from utils.source_data_analysis_utils import get_png_sizes
from utils.source_data_analysis_utils import plot_image_sizes
from utils.source_data_analysis_utils import plot_random_images
from utils.prepare_lr_dataset import reduce_resolution_parallel

# %%
source_dir='../data/valid/hr_images'
dest_dir='../data/valid/lr_images'
target_width=32
target_height=32
postfix='_0'
reduce_resolution_parallel(source_dir, dest_dir, target_width, target_height, postfix)
# Out:
# Resizing process started
# Input Data Size: 10000
# Resizing process finished

# %%
validation_png_sizes = get_png_sizes("../data/valid/lr_images")
plot_random_images(validation_png_sizes, "../data/valid/lr_images")

# %%
plot_image_sizes(validation_png_sizes)

# %%
source_dir='../data/train/hr_images'
dest_dir='../data/train/lr_images'
target_width=32
target_height=32
postfix='_0'
reduce_resolution_parallel(source_dir, dest_dir, target_width, target_height, postfix)
# Out:
# Resizing process started
# Input Data Size: 60000
# Resizing process finished

# %%
png_sizes = get_png_sizes("../data/train/lr_images")
plot_random_images(png_sizes, "../data/train/lr_images")

# %%
plot_image_sizes(png_sizes)
